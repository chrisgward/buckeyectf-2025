# %% [markdown]
# The Professor's Files
# =====================
#
# ## Challenge
# This is a good forensics challenge to start with. Use the help button to ask for a hint if you get stuck.
#
# A professor uploaded their ethics report for review, but something about it seems… off. The document’s formatting feels inconsistent, almost like it was edited by hand rather than exported normally. The metadata looks strange too, and there’s a rumor that the professor hides sensitive data in plain sight
#
# ## Included files
# * OSU_Ethics_Report.docx
#
# ## Analysis
# docx files are compressed zip files with a bunch of XML amongst other things within them, let's start by extracting it, and then search for flags in those files

# %%
# %%bash
# rm -rf extracted
# mkdir extracted
# unzip OSU_Ethics_Report.docx -d extracted
#
# grep -R bctf{ extracted
# Out:
# Archive:  OSU_Ethics_Report.docx
#   inflating: extracted/[Content_Types].xml
#   inflating: extracted/_rels/.rels
#   inflating: extracted/docProps/app.xml
#   inflating: extracted/docProps/core.xml
#   inflating: extracted/docProps/custom.xml
#   inflating: extracted/word/_rels/document.xml.rels
#   inflating: extracted/word/document.xml
#   inflating: extracted/word/fontTable.xml
#   inflating: extracted/word/settings.xml
#   inflating: extracted/word/styles.xml
#   inflating: extracted/word/theme/theme1.xml
# extracted/word/theme/theme1.xml:      <!-- bctf{docx_is_zip} -->
